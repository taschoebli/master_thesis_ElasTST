# %%
# ElasTST Baseline Reproduction by Luzi Schöb

# %%
# Check if CUDA compiler is available
# !nvcc --version

# %%
# Clone ProbTS repo
# !git clone https://github.com/taschoebli/master_thesis_ElasTST.git

# %%
# Switch to directory
# %cd master_thesis_ElasTST
# Out:
# /content/master_thesis_HSG

# %%
#Install required packages
# !pip install .

# %%
#Get datasets
# !bash scripts/prepare_datasets.sh "./datasets"
# !mkdir log_dir

# %%
#Run baseline
# !bash scripts/run_baselines.sh

# %%
#Run other model
# !bash run.sh
